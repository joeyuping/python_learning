# %% [markdown]
# # Generating DataFrame

# %% [markdown]
# ## 1. using Dictionary, value = list (index auto)

# %%
import pandas as pd 
import numpy as np

data = {
    '縣市': ['台北','台北','台北','新竹','新竹','新竹'], 
    # each key:value pair now becomes a Series => Series.name : Series.values
    '年份': [2000,2001,2002,2001,2002,2003],
    '人口': [2.2,2.5,2.7,1.1,1.5,2.0]
}

frame = pd.DataFrame(data)
frame

# note: how the data is transposed!
# Out:
#    縣市    年份   人口
# 0  台北  2000  2.2
# 1  台北  2001  2.5
# 2  台北  2002  2.7
# 3  新竹  2001  1.1
# 4  新竹  2002  1.5
# 5  新竹  2003  2.0

# %%
# creating df using only some of the data by specifying column name

data = {
    '縣市': ['台北','台北','台北','新竹','新竹','新竹'], 
    '年份': [2000,2001,2002,2001,2002,2003],
    '人口': [2.2,2.5,2.7,1.1,1.5,2.0]
}

frame = pd.DataFrame(data, columns=['縣市','年份'])
frame

# note: how the data is transposed!
# Out:
#    縣市    年份
# 0  台北  2000
# 1  台北  2001
# 2  台北  2002
# 3  新竹  2001
# 4  新竹  2002
# 5  新竹  2003

# %%
# by default, row index is a range
# customize row index:

data = {
    '縣市': ['台北','台北','台北','新竹','新竹','新竹'], 
    '年份': [2000,2001,2002,2001,2002,2003],
    '人口': [2.2,2.5,2.7,1.1,1.5,2.0]
}

frame = pd.DataFrame(data, 
                     columns=['縣市','人口','年份'], 
                     index=['one','two','three','four','five','six'])
frame
# Out:
#        縣市   人口    年份
# one    台北  2.2  2000
# two    台北  2.5  2001
# three  台北  2.7  2002
# four   新竹  1.1  2001
# five   新竹  1.5  2002
# six    新竹  2.0  2003

# %%
frame.columns
# Out:
# Index(['縣市', '人口', '年份'], dtype='object')

# %%
frame.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %% [markdown]
# ## 2. using dictionary, value = dictionary (custom index)

# %%
# generating dataframe with dictionary within dictionary:

pop = {'台北':{2001:2.4, 2002:2.9},
      '高雄':{2000:1.5,2001:1.7,2002:3.6}}
frame3 = pd.DataFrame(pop)
frame3
# Out:
#        台北   高雄
# 2001  2.4  1.7
# 2002  2.9  3.6
# 2000  NaN  1.5

# %%
#giving names to the index and columns
frame3.index.name = '年份'
frame3.columns.name = '縣市'
frame3
# Out:
# 縣市     台北   高雄
# 年份
# 2001  2.4  1.7
# 2002  2.9  3.6
# 2000  NaN  1.5

# %% [markdown]
# ## 3. using ndarray

# %%
# using ndarray to generate dataframe:

import numpy as np
import pandas as pd

scores = np.random.randint(50,101,(50,5))
scores_df = pd.DataFrame(scores, columns = ['國文','英文','數學','地理','歷史'],
                        index = range(1,51))
scores_df.index.name = '座號'
scores_df.columns.name = '科目'
scores_df.head()
# Out:
# 科目  國文  英文  數學  地理  歷史
# 座號
# 1   76  80  71  76  71
# 2   79  93  80  83  61
# 3   89  58  60  64  53
# 4   59  89  85  83  51
# 5   80  82  81  70  75

# %%
import numpy as np
import pandas as pd

np1 = np.array([[1,2,3],[4,5,6]])
frame = pd.DataFrame(np1, 
                     index = [5,6],
                     columns = ['台北','台中','高雄'],
                     copy = True)
frame
# Out:
#    台北  台中  高雄
# 5   1   2   3
# 6   4   5   6

# %%
frame = pd.DataFrame(data = np.arange(9).reshape(3,3),
                    index = ['a','b','c'],
                    columns = ['台北','台中','高雄'])
frame
# Out:
#    台北  台中  高雄
# a   0   1   2
# b   3   4   5
# c   6   7   8

# %%
frame.reindex(index=['a','b'],columns)

# %% [markdown]
# ### Note: pd.DataFrame is default to copy = false!

# %%
import numpy as np
import pandas as pd

arr1 = [[1,2,3],[4,5,6]]
ndarr1 = np.array(arr1)  # copy is default to true

df = pd.DataFrame(ndarr1,columns = ['a','b','c']) # copy is default to false!!

display(df)
print(df['a'][1])   # column name a, index 1 item
df['a'][1] = -1
display(df)

ndarr1  # note!!! ndarr1 is manipulated!!
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 4
#    a  b  c
# 0  1  2  3
# 1 -1  5  6
# array([[ 1,  2,  3],
#        [-1,  5,  6]])

# %%
# creating DataFrame without manipulation == copy=True

arr1 = [[1,2,3],[4,5,6]]
ndarr1 = np.array(arr1)  # copy is default to true

df = pd.DataFrame(ndarr1,columns = ['a','b','c'], copy=True) # set copy to True!!

df['a'][1] = -1
display(df)

ndarr1  # note!!! ndarr1 is no longer manipulated!!
# Out:
#    a  b  c
# 0  1  2  3
# 1 -1  5  6
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ## 4.  csv --> 2D list --> DataFrame

# %%
import csv
import numpy as np
import pandas as pd

def convertToInt(string):  #note!! as data may contain none integer value, here use function to try/except
    try:
        return int(string)
    except:
        return 0
    
def convertToFloat(string):
    try:
        return float(string)
    except:
        return 0


datalist = []
with open("各鄉鎮市區人口密度.csv", encoding = "utf-8") as file:
    rows = csv.reader(file)
    for row in rows:
        if row[0] == '107' or row[0] == '統計年':
            if row[0] == '107':
                row[2] = convertToInt(row[2])
                row[3] = convertToFloat(row[3])
                row[4] = convertToInt(row[4])
            datalist.append(row)

'''
#更精簡的寫法！用comprehesion! 
with open("各鄉鎮市區人口密度.csv", encoding = "utf-8") as file:
    datalist = [item for item in list(csv.reader(file)) if item[0] == '107' or item[0] == '統計年']
for row in datalist:
    row[2] = convertToInt(row[2])
    row[3] = convertToFloat(row[3])
    row[4] = convertToInt(row[4])
'''

title = datalist.pop(0) # extracting title row, now datalist has only data
df = pd.DataFrame(datalist, columns=title)
df
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 0    107  新北市板橋區  554742  23.1373  23976
# 1    107  新北市三重區  385826  16.3170  23646
# 2    107  新北市中和區  412486  20.1440  20477
# 3    107  新北市永和區  221098   5.7138  38695
# 4    107  新北市新莊區  417754  19.7383  21165
# ..   ...     ...     ...      ...    ...
# 365  107  連江縣北竿鄉    2425   9.9000    245
# 366  107  連江縣莒光鄉    1618   4.7000    344
# 367  107  連江縣東引鄉    1350   3.8000    355
# 368  107    東沙群島       0   2.3800      0
# 369  107    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %% [markdown]
# ## 5. use pd.read_csv

# %%
import pandas as pd
df = pd.read_csv("各鄉鎮市區人口密度.csv")
df
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             107                                             新北市板橋區
# 2             107                                             新北市三重區
# 3             107                                             新北市中和區
# 4             107                                             新北市永和區
# ..            ...                                                ...
# 370           107                                               南沙群島
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         554742  23.1373              23976
# 2         385826   16.317              23646
# 3         412486   20.144              20477
# 4         221098   5.7138              38695
# ..           ...      ...                ...
# 370            …   0.5045                  …
# 371          NaN      NaN                NaN
# 372          NaN      NaN                NaN
# 373          NaN      NaN                NaN
# 374          NaN      NaN                NaN
#
# [375 rows x 5 columns]

# %%
# but note : using pd.read_csv, come in all string. cannot do comparisons
df.dtypes
# Out:
# statistic_yyy         object
# site_id               object
# people_total          object
# area                  object
# population_density    object
# dtype: object

# %%
# !type 各鄉鎮市區人口密度.csv
# nice way to read whats in the file before-hand!
# Out:
# ﻿statistic_yyy,site_id,people_total,area,population_density
# 統計年,區域別,年底人口數,土地面積,人口密度
# 107,新北市板橋區,554742,23.1373,23976
# 107,新北市三重區,385826,16.317,23646
# 107,新北市中和區,412486,20.144,20477
# 107,新北市永和區,221098,5.7138,38695
# 107,新北市新莊區,417754,19.7383,21165
# 107,新北市新店區,302231,120.2255,2514
# 107,新北市樹林區,183946,33.1288,5552
# 107,新北市鶯歌區,86361,21.1248,4088
# 107,新北市三峽區,115820,191.4508,605
# 107,新北市淡水區,173502,70.6565,2456
# 107,新北市汐止區,200535,71.2354,2815
# 107,新北市瑞芳區,39982,70.7336,565
# 107,新北市土城區,236901,29.5578,8015
# 107,新北市蘆洲區,201332,7.4351,27079
# 107,新北市五股區,86329,34.8632,2476
# 107,新北市泰山區,78708,19.1603,4108
# 107,新北市林口區,110081,54.1519,2033
# 107,新北市深坑區,23634,20.5787,1148
# 107,新北市石碇區,7731,144.3498,54
# 107,新北市坪林區,6612,170.835,39
# 107,新北市三芝區,22978,65.9909,348
# 107,新北市石門區,12115,51.2645,236
# 107,新北市八里區,38906,39.4933,985
# 107,新北市平溪區,4666,71.3382,65
# 107,新北市雙溪區,8860,146.2484,61
# 107,新北市貢寮區,12301,99.9734,123
# 107,新北市金山區,21774,49.2132,442
# 107,新北市萬里區,22068,63.3766,348
# 107,新北市烏來區,6438,321.1306,20
# 107,臺北市松山區,205702,9.2878,22148
# 107,臺北市信義區,223406,11.2077,19933
# 107,臺北市大安區,308843,11.3614,27184
# 107,臺北市中山區,229456,13.6821,16771
# 107,臺北市中正區,159000,7.6071,20902
# 107,臺北市大同區,127625,5.6815,22463
# 107,屏東縣長治鄉,29677,39.8861,744
# 107,屏東縣麟洛鄉,11036,16.26,679
# 107,屏東縣九如鄉,22061,42.0187,525
# 107,屏東縣里港鄉,26044,68.9208,378
# 107,屏東縣鹽埔鄉,25719,64.3493,400
# 107,屏東縣高樹鄉,24384,90.1522,270
# 107,屏東縣萬巒鄉,20593,60.7315,339
# 107,屏東縣內埔鄉,54115,81.8554,661
# 107,屏東縣竹田鄉,17119,29.0732,589
# 107,屏東縣新埤鄉,9981,59.0102,169
# 107,屏東縣枋寮鄉,24323,57.7347,421
# 107,屏東縣新園鄉,34880,38.3109,910
# 107,屏東縣崁頂鄉,15519,31.2659,496
# 107,屏東縣林邊鄉,17795,15.6233,1139
# 107,屏東縣南州鄉,10639,18.97,561
# 107,屏東縣佳冬鄉,19121,30.9842,617
# 107,屏東縣琉球鄉,12364,6.8018,1818
# 107,屏東縣車城鄉,8577,49.8517,172
# 107,屏東縣滿州鄉,7968,142.2013,56
# 107,屏東縣枋山鄉,5498,17.2697,318
# 107,屏東縣三地門鄉,7697,196.3965,39
# 107,屏東縣霧臺鄉,3354,278.796,12
# 107,屏東縣瑪家鄉,6829,78.7008,87
# 107,屏東縣泰武鄉,5392,118.6266,45
# 107,屏東縣來義鄉,7433,167.7756,44
# 107,屏東縣春日鄉,4909,160.001,31
# 107,屏東縣獅子鄉,4954,301.0018,16
# 107,屏東縣牡丹鄉,4981,181.8366,27
# 107,臺東縣臺東市,105573,109.7691,962
# 107,臺東縣成功鎮,14059,143.9939,98
# 107,臺東縣關山鎮,8703,58.7351,148
# 107,臺東縣卑南鄉,17269,412.6871,42
# 107,臺東縣大武鄉,6046,69.1454,87
# 107,臺東縣太麻里鄉,11147,96.6523,115
# 107,臺東縣東河鄉,8479,210.1908,40
# 107,臺東縣長濱鄉,7182,155.1868,46
# 107,臺東縣鹿野鄉,7875,89.698,88
# 107,臺東縣池上鄉,8199,82.6854,99
# 107,臺東縣綠島鄉,4097,15.0919,271
# 107,臺東縣延平鄉,3628,455.8805,8
# 107,臺東縣海端鄉,4186,880.0382,5
# 107,臺東縣達仁鄉,3580,306.4454,12
# 107,臺東縣金峰鄉,3739,380.6635,10
# 107,臺東縣蘭嶼鄉,5157,48.3892,107
# 107,花蓮縣花蓮市,103841,29.4095,3531
# 107,花蓮縣鳳林鎮,10846,120.5181,90
# 107,花蓮縣玉里鎮,24007,252.3719,95
# 107,花蓮縣新城鄉,20159,29.4095,685
# 107,花蓮縣吉安鄉,83221,65.2582,1275
# 107,花蓮縣壽豐鄉,17949,218.4448,82
# 107,花蓮縣光復鄉,12789,157.11,81
# 107,花蓮縣豐濱鄉,4752,162.4332,29
# 107,花蓮縣瑞穗鄉,11668,135.5862,86
# 107,花蓮縣富里鄉,10277,176.3705,58
# 107,花蓮縣秀林鄉,15939,1641.8555,10
# 107,花蓮縣萬榮鄉,6419,618.491,10
# 107,花蓮縣卓溪鄉,6101,1021.313,6
# 107,澎湖縣馬公市,62610,33.9918,1842
# 107,澎湖縣湖西鄉,14594,33.3008,438
# 107,澎湖縣白沙鄉,9827,20.0875,489
# 107,澎湖縣西嶼鄉,8349,18.7148,446
# 107,澎湖縣望安鄉,5235,13.7824,380
# 107,澎湖縣七美鄉,3825,6.9868,547
# 107,基隆市中正區,51670,10.2118,5060
# 107,基隆市七堵區,53782,56.2659,956
# 107,基隆市暖暖區,38619,22.8283,1692
# 107,基隆市仁愛區,43730,4.2335,10330
# 107,基隆市中山區,47398,10.5238,4504
# 107,基隆市安樂區,82294,18.025,4566
# 107,基隆市信義區,52662,10.6706,4935
# 107,新竹市東區,215566,33.5768,6420
# 107,新竹市北區,151679,15.7267,9645
# 107,新竹市香山區,78390,54.8491,1429
# 107,嘉義市東區,121162,30.1556,4018
# 107,嘉義市西區,147460,29.87,4937
# 107,金門縣金城鎮,43325,21.713,1995
# 107,金門縣金湖鎮,29856,41.696,716
# 107,金門縣金沙鎮,20784,41.19,505
# 107,金門縣金寧鄉,31765,29.854,1064
# 107,金門縣烈嶼鄉,12861,16.003,804
# 107,金門縣烏坵鄉,682,1.2,568
# 107,連江縣南竿鄉,7663,10.4,737
# 107,連江縣北竿鄉,2425,9.9,245
# 107,連江縣莒光鄉,1618,4.7,344
# 107,連江縣東引鄉,1350,3.8,355
# 107,東沙群島,…,2.38,…
# 107,南沙群島,…,0.5045,…
# ,,,,
# ,說明：1.人口密度係指每單位土地面積內之人口數。,,,
# ,2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里),,,
# ,，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。,,,

# %%
# use arguments of pd.read_csv to do initial manipulations of data!

def convertToInt(string):  #note!! as data may contain none integer value, here use function to try/except
    try:
        return int(string)
    except:
        return 0
    
def convertToFloat(string):
    try:
        return float(string)
    except:
        return 0

df = pd.read_csv("各鄉鎮市區人口密度.csv", 
                 header = 1, 
                 converters = {'年底人口數':convertToInt,'土地面積':convertToFloat,'人口密度':convertToInt},
                 nrows = 370)
df
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 0    107  新北市板橋區  554742  23.1373  23976
# 1    107  新北市三重區  385826  16.3170  23646
# 2    107  新北市中和區  412486  20.1440  20477
# 3    107  新北市永和區  221098   5.7138  38695
# 4    107  新北市新莊區  417754  19.7383  21165
# ..   ...     ...     ...      ...    ...
# 365  107  連江縣北竿鄉    2425   9.9000    245
# 366  107  連江縣莒光鄉    1618   4.7000    344
# 367  107  連江縣東引鄉    1350   3.8000    355
# 368  107    東沙群島       0   2.3800      0
# 369  107    南沙群島       0   0.5045      0
#
# [370 rows x 5 columns]

# %% [markdown]
# ## 6. using pd.Series

# %%
import pandas as pd
a = pd.Series([1,2,3],name = 'a')
b = pd.Series([4,5,6],name = 'b')

display(pd.DataFrame((a,b))) # merge as rows

display(pd.concat((a,b),axis = 1)) # merge as columns
# Out:
#    0  1  2
# a  1  2  3
# b  4  5  6
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
