# %%
import seaborn as sns
import numpy as np
import pandas as pd

y = pd.Series([2,6,5,8,10,14,15],name='y')
x = pd.Series(np.arange(len(y)),name='x')
data = pd.concat((x,y),axis =1)

x_plot = np.linspace(0,6,100).reshape(-1,1)

sns.lmplot(x='x',y='y',data= data, fit_reg = True)
